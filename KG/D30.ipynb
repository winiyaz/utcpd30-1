# %% [markdown]
# <div style="background: black; color: #00ff00; padding: 2px; text-align: center;background-size: cover; padding: 10px; text-shadow: 00 0 20px #ec4899">
#     <h1>Day30 - Errors Exception Handling</h1>
#
# </div>
#
# 1. [`Colors`](https://rich.readthedocs.io/en/latest/appendix/colors.html?highlight=colors) _ list of standard colors that can be printed out
# 2. [`Ascii Banne Generator`](https://manytools.org/hacker-tools/ascii-banner/) - Used this to generate nice banners below
# 3. [`AsciiFlow`](https://asciiflow.com/#/) - Draw ASCII digrams you can then use this

# %%
# Prettifier # Prettifier
# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
from rich.style import Style # For styles colors
from rich.text import Text # For text Styles
console = Console() # Standard code to access console
# from rich.traceback import install
# install(show_locals=True)
# -------------------------------------------------------

# %% [markdown]
# # Catching Exceptions

# %%
# Listing out director structure 

import os

# Running a simple command
os.system("ls -l")

# Getting environment variables
print(os.environ.get("PATH"))
# Out:
# total 0
# /opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin

# %%
# Writing a file to filesystem and then 
import json
import os

# Example object
data = {
    "name": "John Doe",
    "age": 30,
    "city": "New York"
}

# Writing to a text file
with open('data.txt', 'w') as file:
    json.dump(data, file, indent=4)

# View File
os.system("ls -l")
os.system("cat data.txt")
# Out:
# total 4
# -rw-r--r-- 1 root root 65 Aug 24 09:31 data.txt
# {
#     "name": "John Doe",
#     "age": 30,
#     "city": "New York"
# }
# 0

# %%
# Testing exceptions 

def open_file(filenam):
    with open(filenam) as file:
        file.read()

# Running file 
open_file("gi.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 8
#       5         file.read()
#       7 # Running file
# ----> 8 open_file("gi.txt")
#
# Cell In[5], line 4, in open_file(filenam)
#       3 def open_file(filenam):
# ----> 4     with open(filenam) as file:
#       5         file.read()
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gi.txt'

# %%
# Key Error 
a_dict = {"key": "value"}
value = a_dict["non_existent_key"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Key Error
#       2 a_dict = {"key": "value"}
# ----> 3 value = a_dict["non_existent_key"]
#
# KeyError: 'non_existent_key'

# %%
# List error 

a_list = ["apple", "mango", "banana"]
print(a_list[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 4
#       1 # List error
#       3 a_list = ["apple", "mango", "banana"]
# ----> 4 print(a_list[4])
#
# IndexError: list index out of range

# %%
# Type error 
text = 'abc'
print(text + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Type error
#       2 text = 'abc'
# ----> 3 print(text + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Handling Exception

# %%
import subprocess
import json

# Catching Exception 
try:
    file = open('tt.txt')
except:
    rprint('Fucked Bastard - File Being written')    
    write_pnty=["Panty Smell"]
    with open('tt.txt', 'w') as file:
        json.dump(write_pnty, file, indent=4)
    

# List file 
subprocess.run(["ls", "-al", "tt.txt"])
subprocess.run(["cat", "tt.txt"])
# Out:
# -rw-r--r-- 1 root root 0 Aug 24 09:42 tt.txt
# CompletedProcess(args=['cat', 'tt.txt'], returncode=0)

# %% [markdown]
# ## Writing file using python
#
# 1. Note you were getting erros since you keep trying to open and check for the same file.
# 2. Now you made it into a constant to run the code multiple times and check output

# %%
# Taken from mistrk

import os
import json
import subprocess

# Constant file name
file_name = "t4.txt"

# Check if the file exists
if not os.path.exists(file_name):
    print('File not found - Creating and writing to the file')
    write_pnty = ["Panty Smell"]
    with open(file_name,'w') as file:
        json.dump(write_pnty, file, indent=4)

# List file and display its contents
subprocess.run(["ls", "-al", file_name])
subprocess.run(["cat", file_name])
# Out:
# File not found - Creating and writing to the file
# -rw-r--r-- 1 root root 21 Aug 24 10:27 t4.txt
# [
#     "Panty Smell"
# ]
# CompletedProcess(args=['cat', 't4.txt'], returncode=0)

# %% [markdown]
# # Returning back Tutorial

# %%
# Read the file below
import os 
os.system('cat n1.txt')
# Out:
# 0

# %% [markdown]
# # Catching various exception
#
# 1. Below catching exception

# %%
# Delete txt files
import os 
os.system("ls -al *.txt")
os.system("cat *.txt")
os.system("rm *.txt")
# Out:
# -rw-r--r-- 1 root root 9 Aug 24 11:04 n4.txt
# LicknSuck
# 0

# %%
# Contiuing code from pnty

#File Constant
FILE1 = "n4.txt"

try:
    
    file = open(FILE1)
    a_dict = {"type": "sniff"}
    rprint(a_dict["gi"])
    
except FileNotFoundError:
    
    file = open(FILE1, "w")
    file.write("LicknSuck") # Writing direct to file 
    rprint("NoFile")

except KeyError as err_msg:
    
    rprint(err_msg)
    rprint('bastardNokey')

else: 
    
    content = file.read()
    rprint(content)

finally: # Not usually used
    
    file.close()
    rprint('Closed')
# Out:
# 'gi'
# bastardNokey
# Closed

# %% [markdown]
# # Raising own exceptions
# - You can make you own exceptions also

# %%
# Contiuing code from pnty

#File Constant
FILE1 = "n4.txt"

try:
    
    file = open(FILE1)
    a_dict = {"type": "sniff"}
    rprint(a_dict["gi"])
    
except FileNotFoundError:
    
    file = open(FILE1, "w")
    file.write("LicknSuck") # Writing direct to file 
    rprint("NoFile")

except KeyError as err_msg:
    
    rprint(err_msg)
    rprint('bastardNokey')

else: 
    
    content = file.read()
    rprint(content)

finally: # Not usually used
    
    raise KeyError("AHAHA Just fucking with you ")
# Out:
# 'gi'
# bastardNokey
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 30
#      26     rprint(content)
#      28 finally: # Not usually used
# ---> 30     raise KeyError("AHAHA Just fucking with you ")
#
# KeyError: 'AHAHA Just fucking with you '

# %% [markdown]
# ## Testing out making own excetions

# %%
# Creating erroer 
het = float(input("Enter Height: "))
wet = int(input("Enter Weight: "))

if het > 3:
    raise ValueError("Heigth  > 3m")

bmi = wet/het ** 2

print(bmi)
# Out:
# Enter Height:  4
# Enter Weight:  12
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 6
#       3 wet = int(input("Enter Weight: "))
#       5 if het > 3:
# ----> 6     raise ValueError("Heigth  > 3m")
#       8 bmi = wet/het ** 2
#      10 print(bmi)
#
# ValueError: Heigth  > 3m
